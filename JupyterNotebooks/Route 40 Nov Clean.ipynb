# %% [markdown]
# Getting routes

# %%
import pandas as pd
from collections import OrderedDict

# Import package numpy for numeric computing
import numpy as np

# Import package matplotlib for visualisation/plotting
import matplotlib.pyplot as plt

#For showing plots directly in the notebook
# %matplotlib inline

# %%
df = pd.read_csv('route40CLEAN.csv') # change for route (possibly programm to run all
df.columns = ['Timestamp', 'LineID', 'Direction', 'JourneyPatternID', 'TimeFrame', 'VehicleJourneyID', 'Operator', 'Congestion', 'Longitude', 'Latitude', 'Delay', 'BlockID', 'VehicleID', 'StopID', 'AtStop', 'Date']
df.head(1)
# Out:
#           Timestamp  LineID  Direction JourneyPatternID   TimeFrame  \
# 0  1352184864000000    40.0          0             null  2012-11-06
#
#    VehicleJourneyID Operator  Congestion  Longitude   Latitude  Delay  \
# 0              2510       HN           0  -6.260334  53.353134      0
#
#    BlockID  VehicleID StopID  AtStop                 Date
# 0    40207      33279   null       0  2012-11-06 06:54:24

# %%
df.shape
# Out:
# (1176673, 16)

# %%
#df= df.dropna( how='any', subset = ['JourneyPatternID', 'StopID'])
df=df[df.JourneyPatternID != 'null']

# %%
df=df[df.StopID != 'null']
df.head(1)
# Out:
#           Timestamp  LineID  Direction JourneyPatternID   TimeFrame  \
# 2  1352184864000000    40.0          0         00400001  2012-11-06
#
#    VehicleJourneyID Operator  Congestion  Longitude   Latitude  Delay  \
# 2              6408       HN           0  -6.346193  53.342491   -395
#
#    BlockID  VehicleID StopID  AtStop                 Date
# 2    40104      33278   2712       0  2012-11-06 06:54:24

# %%
df.shape
# Out:
# (971563, 16)

# %%
df= df.dropna( how='any', subset = ['JourneyPatternID', 'StopID'])
df['JourneyPatternID'].unique()
# Out:
# array(['00400001', '040D0002', '00401001', '040D1002', '040B1001',
#        '040B0001', '00400002', '040D1001', '040D0001', '00400004',
#        '00401002', '00680004', '040B0002'], dtype=object)

# %%
df2 = df[df['JourneyPatternID'] == '00400001' ]

# %%
#df1['StopID'].unique()

# %%
#df2 = df1[df1['AtStop'] == 1]
#not necessary or accurate if not normally at stop

# %%
#df2['StopID'].unique()

# %%
#df2['StopID'].value_counts()

# %%
#df2.VehicleJourneyID.value_counts()
df2['Date'] = pd.to_datetime(df2['Date'])
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_mon = df2[df2['Date'].dt.dayofweek == 0]
df_tues = df2[df2['Date'].dt.dayofweek == 1]
df_wed = df2[df2['Date'].dt.dayofweek == 2]
df_thurs = df2[df2['Date'].dt.dayofweek == 3]
df_fri = df2[df2['Date'].dt.dayofweek == 4]
df_sat = df2[df2['Date'].dt.dayofweek == 5]
df_sun = df2[df2['Date'].dt.dayofweek == 6]

# %%
df_mon6 = df_mon[df_mon['Date'].dt.hour >= 6]

# %%
df_mon6 = df_mon6[df_mon6['Date'].dt.hour <= 23]

# %%
jid = df_mon6['VehicleJourneyID'].unique()

# %%
for j in jid:
    df_temp = df_mon[df_mon['VehicleJourneyID'] == j ]
    temp1 = df_temp.head(1)
    c = int(temp1['Timestamp'])
    stops = df_temp.StopID.unique() 

    for i in stops:
        temp = df_temp[df_temp['StopID'] == i ].head(1)
        StopID = int(temp['StopID'])
        b = int(temp['Timestamp'])
        seconds = (b-c)/1000000
        df_mon['Seconds'] = seconds
   # print ("StopID and time in seconds")
   # print (data)
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-626d9f635092> in <module>()
#       6
#       7     for i in stops:
# ----> 8         temp = df_temp[df_temp['StopID'] == i ].head(1)
#       9         StopID = int(temp['StopID'])
#      10         b = int(temp['Timestamp'])
#
# C:\Users\Daniel\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# ...

# %%
df_mon
# Out:
#                Timestamp  LineID  Direction JourneyPatternID   TimeFrame  \
# 264888  1352703346000000    40.0          0         00400001  2012-11-12
# 264890  1352703346000000    40.0          0         00400001  2012-11-12
# 264893  1352703348000000    40.0          0         00400001  2012-11-12
# 264895  1352703348000000    40.0          0         00400001  2012-11-12
# 264901  1352703350000000    40.0          0         00400001  2012-11-12
# 264917  1352703362000000    40.0          0         00400001  2012-11-12
# 264924  1352703364000000    40.0          0         00400001  2012-11-12
# 264926  1352703364000000    40.0          0         00400001  2012-11-12
# 264927  1352703364000000    40.0          0         00400001  2012-11-12
# 264929  1352703366000000    40.0          0         00400001  2012-11-12
# 264938  1352703370000000    40.0          0         00400001  2012-11-12
# 264949  1352703384000000    40.0          0         00400001  2012-11-12
# ...

# %%
df_tues['StopID'].unique()
# Out:
# array(['2712', '1533', '1549', '1942', '261', '2674', '2675', '1943',
#        '1523', '1944', '1534', '2124', '1535', '2125', '270', '2655',
#        '1524', '2126', '1536', '1525', '2128', '1537', '1526', '186',
#        '2668', '6080', '2129', '1945', '335', '838', '2672', '1946', '839',
#        '1947', '4797', '1585', '2673', '7473', '840', '1586', '2642',
#        '2206', '2643', '4592', '2681', '4521', '4798', '1587', '4691',
#        '2682', '2644', '4539', '4796', '2709', '841', '4690', '2711',
#        '1935', '4411', '4937', '1606', '1547', '2127', '1548', '1607',
#        '2656', '1937', '49', '1608', '1938', '1609', '4715', '1939',
#        '1610', '7471', '51', '1940', '1941', '52', '4795', '2710', '1989'], dtype=object)

# %%
df_wed['StopID'].unique()
# Out:
# array(['1549', '2206', '1533', '1947', '2129', '841', '1523', '49', '4798',
#        '1534', '2642', '2643', '4797', '51', '7473', '1535', '1524',
#        '2674', '2644', '1525', '2709', '2681', '2675', '1536', '2710',
#        '4691', '1526', '2124', '1537', '2712', '52', '4796', '2125',
#        '2126', '6080', '186', '838', '2128', '4592', '4411', '2655', '839',
#        '1586', '261', '840', '4937', '1587', '2656', '2668', '1548',
#        '4539', '270', '2672', '2673', '1606', '4715', '1607', '1608',
#        '1609', '2682', '1610', '4690', '335', '7471', '2127', '1585',
#        '4521', '4795', '1935', '1937', '1938', '1939', '1940', '1941',
#        '1942', '1943', '1944', '1945', '1946', '2711', '1547', '4799'], dtype=object)

# %%
stops = df2.StopID.unique()

# %%
#df2['StopID'] = df2['StopID'].astype(int)
stops
# Out:
# array(['2712', '1533', '1549', '1942', '261', '2674', '2675', '1943',
#        '1523', '1944', '1534', '2124', '1535', '2125', '270', '2655',
#        '1524', '2126', '1536', '1525', '2128', '1537', '1526', '186',
#        '2668', '6080', '2129', '1945', '335', '838', '2672', '1946', '839',
#        '1947', '4797', '1585', '2673', '7473', '840', '1586', '2642',
#        '2206', '2643', '4592', '2681', '4521', '4798', '1587', '4691',
#        '2682', '2644', '4539', '4796', '2709', '841', '4690', '2711',
#        '1935', '4411', '4937', '1606', '1547', '2127', '1548', '1607',
#        '2656', '1937', '49', '1608', '1938', '1609', '4715', '1939',
#        '1610', '7471', '51', '1940', '1941', '52', '4795', '2710', '2679',
#        '2680', '1989', '7', '4688', '7510', '2696', '279', '2676', '4799'], dtype=object)

# %%
#As dicts aren't ordered, and order of stops is important OrderedDict is necessary
data = OrderedDict()
temp1 = df2.head(1)
c = int(temp1['Timestamp'])

for i in stops:
    temp = df2[df2['StopID'] == i ].head(1)
    StopID = int(temp['StopID'])
    b = int(temp['Timestamp'])
    seconds = (b-c)/1000000
    data[StopID] = seconds
print ("StopID and time in seconds")
print (data)
    
#get average time from stops to 
#new_df.append(data, ignore_index=True)
# Out:
# StopID and time in seconds
# ...

# %%
#As dicts aren't ordered, and order of stops is important OrderedDict is necessary
data = OrderedDict()
temp1 = df2.head(1)
c = int(temp1['Timestamp'])

for i in stops:
    temp = df2[df2['StopID'] == i ].head(1)
    StopID = int(temp['StopID'])
    b = int(temp['Timestamp'])
    seconds = (b-c)/1000000
    data[StopID] = seconds
print ("StopID and time in seconds")
print (data)
    

#new_df.append(data, ignore_index=True)
# Out:
# StopID and time in seconds
# ...
